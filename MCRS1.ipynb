# %%
import pandas as pd
import json

# %%
data1 = json.load(open('E:/Research Project/Json data/json/100407.json'))
df1 = pd.DataFrame(data1["Reviews"])

data2 = json.load(open('E:/Research Project/Json data/json/100504.json'))
df2 = pd.DataFrame(data3["Reviews"])

list = pd.read_csv("E:/Research Project/list.csv")
list.head()
# Out:
#     Name
# 0  72572
# 1  72579
# 2  72586
# 3  73718
# 4  73727

# %%
df2.columns
# Out:
# Index(['Author', 'AuthorLocation', 'Content', 'Date', 'Ratings', 'ReviewID',
#        'Title'],
#       dtype='object')

# %%
df11 = df1[['Ratings', "Author"]]
df11['hotelID'] = "100407"
df22 = df2[['Ratings', "Author"]]
df22['hotelID'] = "100504"
result = pd.DataFrame()
result = pd.concat([df11, df22])
# Out:
# E:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# E:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
result.head()
# Out:
#                                              Ratings        Author hotelID
# 0  {'Service': '5', 'Cleanliness': '5', 'Overall'...      Nadine R  100407
# 1  {'Service': '4', 'Cleanliness': '4', 'Overall'...       blt3116  100407
# 2  {'Service': '5', 'Cleanliness': '5', 'Overall'...       ExSpec5  100407
# 3  {'Service': '5', 'Cleanliness': '5', 'Overall'...   kevinlynch3  100407
# 4  {'Service': '5', 'Cleanliness': '5', 'Overall'...  nobumponalog  100407

# %%
#import glob
#path = os.path.expanduser("E:\Research Project\Json datajson*.json")

i=0
for fname in list.Name:
    #head, tail = os.path.split(fname)
    #print(fname)
    jData = json.load(open('E:/Research Project/Json data/json/'+str(fname)+'.json'))
    df = pd.DataFrame(jData["Reviews"])
    if 'Ratings' in df and "Author" in df:
        dff = df[['Ratings', "Author"]]
        dff['hotelID'] = str(fname)
        result = pd.concat([result,dff])
        print(i, str(fname))
        i=i+1
# Out:
# E:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# 0 72572
# 1 72579
# 2 72586
# 3 73718
# 4 73727
# 5 73739
# 6 73757
# 7 73787
# 8 73799
# 9 73821
# 10 73855
# 11 73923
# 12 73943
# 13 73947
# 14 73950
# 15 73957
# 16 73985
# 17 74051
# 18 74583
# 19 74626
# 20 75662
# 21 76061
# 22 76083
# 23 76442
# 24 77055
# 25 77264
# 26 77270
# 27 77274
# 28 77629
# 29 77638
# 30 77700
# 31 77714
# 32 77775
# 33 77804
# 34 77827
# 35 77866
# 36 77917
# 37 77944
# 38 78046
# 39 78682
# 40 78688
# 41 78694
# 42 79500
# 43 80083
# 44 80087
# 45 80275
# 46 80747
# 47 80756
# 48 80771
# 49 80774
# 50 80780
# 51 80784
# 52 80786
# 53 80788
# 54 80793
# 55 80797
# 56 80799
# 57 80802
# ...

# %%
result.count()
# Out:
# Ratings    350601
# Author     350601
# hotelID    350601
# dtype: int64

# %%
len(result.Author.unique())
#result.loc[result['Author'] == "Bo94114"]
#len(result.hotelID.unique())
# Out:
# 258520

# %%
res.head()
# Out:
#                                                Ratings                Author  \
# 0    {'Service': '5', 'Cleanliness': '5', 'Overall'...              Nadine R
# 1    {'Service': '4', 'Cleanliness': '4', 'Overall'...               blt3116
# 2    {'Service': '5', 'Cleanliness': '5', 'Overall'...               ExSpec5
# 3    {'Service': '5', 'Cleanliness': '5', 'Overall'...           kevinlynch3
# 4    {'Service': '5', 'Cleanliness': '5', 'Overall'...          nobumponalog
# 5    {'Service': '5', 'Cleanliness': '5', 'Overall'...               pac0101
# 6    {'Cleanliness': '5', 'Sleep Quality': '5', 'Ov...                jcfbgk
# 7    {'Cleanliness': '4', 'Sleep Quality': '3', 'Ov...               Alps110
# 8    {'Cleanliness': '4', 'Sleep Quality': '4', 'Ov...                mspenn
# 9    {'Cleanliness': '5', 'Sleep Quality': '5', 'Ov...          txpeachy1977
# 10   {'Cleanliness': '5', 'Sleep Quality': '5', 'Ov...              MDcouple
# ...

# %%
Rating = result['Ratings'].values.tolist()
IDs = result[['hotelID', "ReviewID"]]
rate = pd.DataFrame(Rating, 
               columns =['Service', 'Cleanliness','Overall','Value','Sleep Quality','Rooms','Location']) 
rate.head()
# Out:
#   Service Cleanliness Overall Value Sleep Quality Rooms Location
# 0       5           5     5.0     5             5     5        5
# 1       4           4     4.0     4             4     4        5
# 2       5           5     4.0     3             3     5        5
# 3       5           5     5.0     4             5     5        5
# 4       5           5     5.0     4             5     5        5

# %%
rate = pd.DataFrame(rate)
IDs  = pd.DataFrame(IDs)
final = IDs.join(rate)

# %%
final.count()
# Out:
# hotelID          350601
# ReviewID         350601
# Service          324436
# Cleanliness      324913
# Overall          350601
# Value            325841
# Sleep Quality    209973
# Rooms            284793
# Location         274242
# dtype: int64

# %%
final.head()
# Out:
#   hotelID     ReviewID Service Cleanliness Overall Value Sleep Quality Rooms  \
# 0  100407  UR128178025       5           5     5.0     5             5     5
# 0  100504  UR126997138       5           5     5.0     5             5     5
# 0   72572  UR126946257       5           5     5.0     5             5     5
# 0   72579  UR126815874       5           5     5.0     5             5     5
# 0   72586  UR126512536       5           5     5.0     5             5     5
#
#   Location
# 0        5
# 0        5
# 0        5
# 0        5
# 0        5
